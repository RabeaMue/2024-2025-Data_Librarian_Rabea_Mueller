# %% [markdown]
# # Retrieve data from the crossref API and extract items from the data in JSON format

# %%
import urllib.request
import json

# %%
base_url = "https://api.crossref.org/works/"
doi = "10.1371/journal.pcbi.1012170"

# Contruct the full URL based on the general base URL and the specific DOI
full_url = base_url + doi

# %%
# Retrieving the data - at this stage this is a very long string
doi_json_data = urllib.request.urlopen(full_url).read()

# %%
# Commands starting with "%" are Jupyter/IPython related
# https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %who
# Out:
# base_url	 complete_url	 doi	 doi_json_data	 full_url	 json	 urllib

# %%
print(doi_json_data)
# Out:
# b'{"status":"ok","message-type":"work","message-version":"1.0.0","message":{"indexed":{"date-parts":[[2024,6,21]],"date-time":"2024-06-21T00:23:38Z","timestamp":1718929418656},"reference-count":31,"publisher":"Public Library of Science (PLoS)","issue":"6","license":[{"start":{"date-parts":[[2024,6,20]],"date-time":"2024-06-20T00:00:00Z","timestamp":1718841600000},"content-version":"vor","delay-in-days":0,"URL":"http:\\/\\/creativecommons.org\\/licenses\\/by\\/4.0\\/"}],"funder":[{"DOI":"10.13039\\/501100001659","name":"Deutsche Forschungsgemeinschaft","doi-asserted-by":"publisher","award":["460129525"],"id":[{"id":"10.13039\\/501100001659","id-type":"DOI","asserted-by":"publisher"}]},{"DOI":"10.13039\\/501100001659","name":"Deutsche Forschungsgemeinschaft","doi-asserted-by":"publisher","award":["442326535"],"id":[{"id":"10.13039\\/501100001659","id-type":"DOI","asserted-by":"publisher"}]}],"content-domain":{"domain":["www.ploscompbiol.org"],"crossmark-restriction":false},"short-container-title":["PLoS Comput Biol"],"DOI":"10.1371\\/journal.pcbi.1012170","type":"journal-article","created":{"date-parts":[[2024,6,20]],"date-time":"2024-06-20T17:38:21Z","timestamp":1718905101000},"page":"e1012170","update-policy":"http:\\/\\/dx.doi.org\\/10.1371\\/journal.pcbi.corrections_policy","source":"Crossref","is-referenced-by-count":0,"title":["Ten simple rules for implementing electronic lab notebooks (ELNs)"],"prefix":"10.1371","volume":"20","author":[{"ORCID":"http:\\/\\/orcid.org\\/0000-0002-9421-8582","authenticated-orcid":true,"given":"Justine","family":"Vandendorpe","sequence":"first","affiliation":[]},{"ORCID":"http:\\/\\/orcid.org\\/0000-0002-8431-6613","authenticated-orcid":true,"given":"Beatrix","family":"Adam","sequence":"additional","affiliation":[]},{"ORCID":"http:\\/\\/orcid.org\\/0000-0002-0363-3837","authenticated-orcid":true,"given":"Jeanne","family":"Wilbrandt","sequence":"additional","affiliation":[]},{"given":"Birte","family":"Lindst\\u00e4dt","sequence":"additional","affiliation":[]},{"given":"Konrad U.","family":"F\\u00f6rstner","sequence":"additional","affiliation":[]}],"member":"340","published-online":{"date-parts":[[2024,6,20]]},"reference":[{"key":"pcbi.1012170.ref001","first-page":"269","article-title":"How to pick an electronic laboratory notebook","volume":"560","author":"R. Kwok","year":"2018","journal-title":"Nature. Springer Science and Business Media LLC"},{"key":"pcbi.1012170.ref002","doi-asserted-by":"crossref","first-page":"78","DOI":"10.1515\\/abitech-2016-0013","article-title":"Elektronische Laborb\\u00fccher im Forschungsdatenmanagement\\u2013Eine neue Aufgabe f\\u00fcr Bibliotheken?","volume":"36","author":"Krause","year":"2016","journal-title":"ABI Technik. Walter de Gruyter GmbH"},{"key":"pcbi.1012170.ref003","volume-title":"Longwood Medical Area Research Data Management Working Group (LMA RDMWG)","author":"Electronic Lab Notebooks","year":"2023"},{"key":"pcbi.1012170.ref004","doi-asserted-by":"crossref","first-page":"179","DOI":"10.1038\\/s41596-021-00645-8","article-title":"Considerations for implementing electronic laboratory notebooks in an academic research environment","volume":"17","author":"SG Higgins","year":"2022","journal-title":"Nature Protocols. Springer Science and Business Media LLC"},{"key":"pcbi.1012170.ref005","first-page":"3","article-title":"The FAIR Guiding Principles for scientific data management and stewardship","author":"MD Wilkinson","year":"2016","journal-title":"Scientific Data. Springer Science and Business Media LLC"},{"key":"pcbi.1012170.ref006","author":"ZB MED\\u2014Information Centre for Life Sciences","year":"2021","journal-title":"ELN Guide. ZB MED\\u2014Informationszentrum Lebenswissenschaften"},{"key":"pcbi.1012170.ref007","unstructured":"ELN Finder [cited 2023 Dec 04]. In: ELN Finder [Internet]. Germany: ZB MED\\u2014Information Centre for Life Sciences & University and State Library Darmstadt. Available from: https:\\/\\/eln-finder.ulb.tu-darmstadt.de\\/hom ...

# %%
# Use the function loads from json to read this JSON formated string and translate
# it into a pythonic object (a very nested dictionary)
doi_data = json.loads(doi_json_data)

# %%
doi_data
# Out:
# {'status': 'ok',
#  'message-type': 'work',
#  'message-version': '1.0.0',
#  'message': {'indexed': {'date-parts': [[2024, 6, 21]],
#    'date-time': '2024-06-21T00:23:38Z',
#    'timestamp': 1718929418656},
#   'reference-count': 31,
#   'publisher': 'Public Library of Science (PLoS)',
#   'issue': '6',
#   'license': [{'start': {'date-parts': [[2024, 6, 20]],
#      'date-time': '2024-06-20T00:00:00Z',
#      'timestamp': 1718841600000},
#     'content-version': 'vor',
#     'delay-in-days': 0,
#     'URL': 'http://creativecommons.org/licenses/by/4.0/'}],
#   'funder': [{'DOI': '10.13039/501100001659',
#     'name': 'Deutsche Forschungsgemeinschaft',
#     'doi-asserted-by': 'publisher',
#     'award': ['460129525'],
#     'id': [{'id': '10.13039/501100001659',
#       'id-type': 'DOI',
#       'asserted-by': 'publisher'}]},
#    {'DOI': '10.13039/501100001659',
#     'name': 'Deutsche Forschungsgemeinschaft',
#     'doi-asserted-by': 'publisher',
#     'award': ['442326535'],
#     'id': [{'id': '10.13039/501100001659',
#       'id-type': 'DOI',
#       'asserted-by': 'publisher'}]}],
#   'content-domain': {'domain': ['www.ploscompbiol.org'],
#    'crossmark-restriction': False},
#   'short-container-title': ['PLoS Comput Biol'],
#   'DOI': '10.1371/journal.pcbi.1012170',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2024, 6, 20]],
#    'date-time': '2024-06-20T17:38:21Z',
#    'timestamp': 1718905101000},
#   'page': 'e1012170',
#   'update-policy': 'http://dx.doi.org/10.1371/journal.pcbi.corrections_policy',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Ten simple rules for implementing electronic lab notebooks (ELNs)'],
#   'prefix': '10.1371',
#   'volume': '20',
#   'author': [{'ORCID': 'http://orcid.org/0000-0002-9421-8582',
#     'authenticated-orcid': True,
#     'given': 'Justine',
#     'family': 'Vandendorpe',
#     'sequence': 'first',
#     'affiliation': []},
#    {'ORCID': 'http://orcid.org/0000-0002-8431-6613',
#     'authenticated-orcid': True,
#     'given': 'Beatrix',
#     'family': 'Adam',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'ORCID': 'http://orcid.org/0000-0002-0363-3837',
#     'authenticated-orcid': True,
#     'given': 'Jeanne',
#     'family': 'Wilbrandt',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Birte',
#     'family': 'Lindstädt',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Konrad U.',
#     'family': 'Förstner',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '340',
#   'published-online': {'date-parts': [[2024, 6, 20]]},
#   'reference': [{'key': 'pcbi.1012170.ref001',
#     'first-page': '269',
#     'article-title': 'How to pick an electronic laboratory notebook',
#     'volume': '560',
#     'author': 'R. Kwok',
#     'year': '2018',
#     'journal-title': 'Nature. Springer Science and Business Media LLC'},
#    {'key': 'pcbi.1012170.ref002',
#     'doi-asserted-by': 'crossref',
#     'first-page': '78',
#     'DOI': '10.1515/abitech-2016-0013',
#     'article-title': 'Elektronische Laborbücher im Forschungsdatenmanagement–Eine neue Aufgabe für Bibliotheken?',
#     'volume': '36',
#     'author': 'Krause',
#     'year': '2016',
#     'journal-title': 'ABI Technik. Walter de Gruyter GmbH'},
#    {'key': 'pcbi.1012170.ref003',
#     'volume-title': 'Longwood Medical Area Research Data Management Working Group (LMA RDMWG)',
#     'author': 'Electronic Lab Notebooks',
#     'year': '2023'},
#    {'key': 'pcbi.1012170.ref004',
#     'doi-asserted-by': 'crossref',
#     'first-page': '179',
#     'DOI': '10.1038/s41596-021-00645-8',
#     'article-title': 'Considerations for implementing electronic laboratory notebooks in an academic research environment',
#     'volume': '17',
#     'author': 'SG Higgins',
#     'year': '2022',
#     'journal-title': 'Nature Protocols. Springer Science and Business Media LLC'},
#    {'key': 'pcbi.1012170.ref005',
#     'first-page': '3',
#     'article-title': 'The FAIR Guiding Principles for scientific data management and stewardship',
#     'author': 'MD Wilkinson',
#     'year': '2016',
#     'journal-title': 'Scientific Data. Springer Science and Business Media LLC'},
#    {'key': 'pcbi.1012170.ref006',
#     'author': 'ZB MED—Information Centre for Life Sciences',
#     'year': '2021',
#     'journal-title': 'ELN Guide. ZB MED—Informationszentrum Lebenswissenschaften'},
#    {'key': 'pcbi.1012170.ref007',
#     'unstructured': 'ELN Finder [cited 2023 Dec 04]. In: ELN Finder [Internet]. Germany: ZB MED—Information Centre for Life Sciences & University and State Library Darmstadt. Available from: https://eln-finder.ulb.tu-darmstadt.de/home.'},
#    {'key': 'pcbi.1012170.ref008',
#     'article-title': 'Electronic Lab Notebook Comparison Matrix',
#     'author': 'Harvard Longwood Medical Area Research Data Management Working Group',
#     'year': '2021',
#     'journal-title': 'Zenodo'},
#    {'key': 'pcbi.1012170.ref009',
#     'author': 'S. Bungers',
#     'year': '2023',
#     'journal-title': 'The Electronic Lab Notebook in 2023: A comprehensive guide.'},
#    {'key': 'pcbi.1012170.ref010',
#     'unstructured': 'How To Choose The Best Electronic Lab Notebook Software. [cited 2024 Mar 01]. In: SciNote Blog [Internet]. Middleton: SciNote 2023. [about 8 screens]. Available from: https://www.scinote.net/blog/electronic-lab-notebook-guide/.'},
#    {'key': 'pcbi.1012170.ref011',
#     'unstructured': 'Electronic Research Notebooks. [cited 2024 Mar 01]. In: University of Cambridge Data Management Guide [Internet]. Cambridge: University of Cambridge; 2024. [about 4 screens]. Available from: https://www.data.cam.ac.uk/data-management-guide/electronic-research-notebooks.'},
#    {'key': 'pcbi.1012170.ref012',
#     'unstructured': 'How ELNs are Shaping R&D Workflows For a More Competitive Future. Uncountable Solutions Guide. [cited 2024 Mar 01]. Available from: https://www.uncountable.com/try/free-guide-electronic-laboratory-notebooks-eln-guide.'},
#    {'key': 'pcbi.1012170.ref013',
#     'article-title': 'eLabFTW: An open source laboratory notebook for research labs',
#     'author': 'N CARPi',
#     'year': '2017',
#     'journal-title': 'GitHub'},
#    {'key': 'pcbi.1012170.ref014',
#     'unstructured': 'ELN demos. [cited 2024 Mar 01]. In: KIT Scientific Computing Center (SCC) [Internet]. Karlsruhe: Scientific Computing Center. 2024. [about 1 screen]. Available from: https://demo.chemotion.scc.kit.edu/.'},
#    {'key': 'pcbi.1012170.ref015',
#     'unstructured': 'Wiki-authors. Vendor lock-in. 2023 Sep 15 [cited 2023 Dec 04]. In: Wikipedia [Internet]. San Francisco: Wikimedia Foundation 2023. [about 3 screens]. Available from: https://en.wikipedia.org/wiki/Vendor_lock-in.'},
#    {'key': 'pcbi.1012170.ref016',
#     'article-title': 'Diskussionspapier Standard4ELN.',
#     'author': 'ZB MED—Information Centre for Life Sciences',
#     'year': '2023',
#     'journal-title': 'ZB MED—Informationszentrum Lebenswissenschaften'},
#    {'key': 'pcbi.1012170.ref017',
#     'unstructured': 'Durbin P. The ELN Consortium. [cited 04 Dec 2023]. In: GitHub [Internet]. San Francisco: GitHub. 2023. Available from: https://github.com/TheELNConsortium.'},
#    {'key': 'pcbi.1012170.ref018',
#     'article-title': 'The ELN File Format. [cited 2023 Dec 04]. In: GitHub',
#     'author': 'S Brinckmann',
#     'year': '2023',
#     'journal-title': 'San Francisco: GitHub'},
#    {'key': 'pcbi.1012170.ref019',
#     'author': 'Wiki-authors',
#     'year': '2023',
#     'journal-title': 'Usability testing'},
#    {'key': 'pcbi.1012170.ref020',
#     'doi-asserted-by': 'crossref',
#     'first-page': 'e1004525',
#     'DOI': '10.1371/journal.pcbi.1004525',
#     'article-title': 'Ten Simple Rules for Creating a Good Data Management Plan',
#     'volume': '11',
#     'author': 'WK Michener',
#     'year': '2015',
#     'journal-title': 'PLoS Comput Biol.'},
#    {'key': 'pcbi.1012170.ref021',
#     'doi-asserted-by': 'crossref',
#     'first-page': '2',
#     'DOI': '10.12688/f1000research.7628.1',
#     'article-title': 'A pocket guide to electronic laboratory notebooks in the academic life sciences',
#     'volume': '5',
#     'author': 'U Dirnagl',
#     'year': '2016',
#     'journal-title': 'F1000Res'},
#    {'key': 'pcbi.1012170.ref022',
#     'unstructured': 'Best Practice Use Guide. [cited 2024 Mar 01]. In: eLabJournal Documentation [Internet]. Groningen: eLabJournal; 2023. [about 1 screen]. Available from: https://www.elabjournal.com/doc/BestPractiseUseGuide.html.'},
#    {'key': 'pcbi.1012170.ref023',
#     'unstructured': 'eLabFTW pricing. [cited 2024 Mar 01]. In: eLabFTW [Internet]. Paris: Deltablot; 2024. [about 3 screens]. Available from: https://www.deltablot.com/elabftw/.'},
#    {'key': 'pcbi.1012170.ref024',
#     'unstructured': 'ZB MED—Information Centre for Life Sciences. Electronic Lab Notebooks (ELN) | Screencast—Infos—und mehr [Video]. 2022 Mar 10. Available from: https://www.youtube.com/playlist?list=PLJYlS0FDTMq17tvYMeuI2Ct5XtykRFy0K.'},
#    {'key': 'pcbi.1012170.ref025',
#     'article-title': 'Community Meeting I, 4:00 p.m.',
#     'author': 'H Uzun',
#     'year': '2024',
#     'journal-title': 'CET, 07 March 2024'},
#    {'key': 'pcbi.1012170.ref026',
#     'volume-title': 'API. 2012 [cited 2024 Mar 01]. In: eLabFTW’s documentation',
#     'author': 'N. CARPi',
#     'year': '2022'},
#    {'key': 'pcbi.1012170.ref027',
#     'article-title': 'Research Space and iRODS Partner to Enable Virtual File Storage and Meta-Data Solutions for Institutional Research Data Management.',
#     'author': 'V. Plankytė',
#     'year': '2022'},
#    {'key': 'pcbi.1012170.ref028',
#     'unstructured': 'Automating Lab Processes with API [Guide with Examples]. [cited 2024 Mar 01]. In: SciNote Blog [Internet]. Middleton: SciNote; 2023. [about 4 screens]. Available from: https://www.scinote.net/blog/automating-lab-processes-with-apis/.'},
#    {'key': 'pcbi.1012170.ref029',
#     'doi-asserted-by': 'crossref',
#     'first-page': '146',
#     'DOI': '10.21105/joss.00146',
#     'article-title': 'eLabFTW: An open source laboratory notebook for research labs',
#     'volume': '2',
#     'author': 'N CARPi',
#     'year': '2017',
#     'journal-title': 'J Open Source Softw'},
#    {'key': 'pcbi.1012170.ref030',
#     'unstructured': 'Tools For Analysis Of Data Stored In Openbis. 2023 Apr 17 [cited 2024 Mar 01]. In: OpenBIS Documentation [Internet]. Portland: Read the Docs; 2022. [about 3 screens]. Available from: https://openbis.readthedocs.io/en/20.10.x/user-documentation/general-users/tools-for-analysis-of-data-stored-in-openbis.html.'},
#    {'key': 'pcbi.1012170.ref031',
#     'year': '2014',
#     'journal-title': 'Research Data: labfolder and figshare cooperate to facilitate dissemination of scientific findings.'}],
#   'container-title': ['PLOS Computational Biology'],
#   'original-title': [],
#   'language': 'en',
#   'link': [{'URL': 'https://dx.plos.org/10.1371/journal.pcbi.1012170',
#     'content-type': 'unspecified',
#     'content-version': 'vor',
#     'intended-application': 'similarity-checking'}],
#   'deposited': {'date-parts': [[2024, 6, 20]],
#    'date-time': '2024-06-20T17:38:32Z',
#    'timestamp': 1718905112000},
#   'score': 1,
#   'resource': {'primary': {'URL': 'https://dx.plos.org/10.1371/journal.pcbi.1012170'}},
#   'subtitle': [],
#   'editor': [{'given': 'Russell',
#     'family': 'Schwartz',
#     'sequence': 'first',
#     'affiliation': []}],
#   'short-title': [],
#   'issued': {'date-parts': [[2024, 6, 20]]},
#   'references-count': 31,
#   'journal-issue': {'issue': '6',
#    'published-online': {'date-parts': [[2024, 6, 20]]}},
#   'URL': 'http://dx.doi.org/10.1371/journal.pcbi.1012170',
#   'relation': {},
#   'ISSN': ['1553-7358'],
#   'issn-type': [{'value': '1553-7358', 'type': 'electronic'}],
#   'subject': [],
#   'published': {'date-parts': [[2024, 6, 20]]}}}

# %%
type(doi_data)
# Out:
# dict

# %%
doi_data.keys()
# Out:
# dict_keys(['status', 'message-type', 'message-version', 'message'])

# %%
# The dictionary has the key "message" which points to a value
# that itself is a dictionary
doi_data["message"]
# Out:
# {'indexed': {'date-parts': [[2024, 6, 21]],
#   'date-time': '2024-06-21T00:23:38Z',
#   'timestamp': 1718929418656},
#  'reference-count': 31,
#  'publisher': 'Public Library of Science (PLoS)',
#  'issue': '6',
#  'license': [{'start': {'date-parts': [[2024, 6, 20]],
#     'date-time': '2024-06-20T00:00:00Z',
#     'timestamp': 1718841600000},
#    'content-version': 'vor',
#    'delay-in-days': 0,
#    'URL': 'http://creativecommons.org/licenses/by/4.0/'}],
#  'funder': [{'DOI': '10.13039/501100001659',
#    'name': 'Deutsche Forschungsgemeinschaft',
#    'doi-asserted-by': 'publisher',
#    'award': ['460129525'],
#    'id': [{'id': '10.13039/501100001659',
#      'id-type': 'DOI',
#      'asserted-by': 'publisher'}]},
#   {'DOI': '10.13039/501100001659',
#    'name': 'Deutsche Forschungsgemeinschaft',
#    'doi-asserted-by': 'publisher',
#    'award': ['442326535'],
#    'id': [{'id': '10.13039/501100001659',
#      'id-type': 'DOI',
#      'asserted-by': 'publisher'}]}],
#  'content-domain': {'domain': ['www.ploscompbiol.org'],
#   'crossmark-restriction': False},
#  'short-container-title': ['PLoS Comput Biol'],
#  'DOI': '10.1371/journal.pcbi.1012170',
#  'type': 'journal-article',
#  'created': {'date-parts': [[2024, 6, 20]],
#   'date-time': '2024-06-20T17:38:21Z',
#   'timestamp': 1718905101000},
#  'page': 'e1012170',
#  'update-policy': 'http://dx.doi.org/10.1371/journal.pcbi.corrections_policy',
#  'source': 'Crossref',
#  'is-referenced-by-count': 0,
#  'title': ['Ten simple rules for implementing electronic lab notebooks (ELNs)'],
#  'prefix': '10.1371',
#  'volume': '20',
#  'author': [{'ORCID': 'http://orcid.org/0000-0002-9421-8582',
#    'authenticated-orcid': True,
#    'given': 'Justine',
#    'family': 'Vandendorpe',
#    'sequence': 'first',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0002-8431-6613',
#    'authenticated-orcid': True,
#    'given': 'Beatrix',
#    'family': 'Adam',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0002-0363-3837',
#    'authenticated-orcid': True,
#    'given': 'Jeanne',
#    'family': 'Wilbrandt',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Birte',
#    'family': 'Lindstädt',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Konrad U.',
#    'family': 'Förstner',
#    'sequence': 'additional',
#    'affiliation': []}],
#  'member': '340',
#  'published-online': {'date-parts': [[2024, 6, 20]]},
#  'reference': [{'key': 'pcbi.1012170.ref001',
#    'first-page': '269',
#    'article-title': 'How to pick an electronic laboratory notebook',
#    'volume': '560',
#    'author': 'R. Kwok',
#    'year': '2018',
#    'journal-title': 'Nature. Springer Science and Business Media LLC'},
#   {'key': 'pcbi.1012170.ref002',
#    'doi-asserted-by': 'crossref',
#    'first-page': '78',
#    'DOI': '10.1515/abitech-2016-0013',
#    'article-title': 'Elektronische Laborbücher im Forschungsdatenmanagement–Eine neue Aufgabe für Bibliotheken?',
#    'volume': '36',
#    'author': 'Krause',
#    'year': '2016',
#    'journal-title': 'ABI Technik. Walter de Gruyter GmbH'},
#   {'key': 'pcbi.1012170.ref003',
#    'volume-title': 'Longwood Medical Area Research Data Management Working Group (LMA RDMWG)',
#    'author': 'Electronic Lab Notebooks',
#    'year': '2023'},
#   {'key': 'pcbi.1012170.ref004',
#    'doi-asserted-by': 'crossref',
#    'first-page': '179',
#    'DOI': '10.1038/s41596-021-00645-8',
#    'article-title': 'Considerations for implementing electronic laboratory notebooks in an academic research environment',
#    'volume': '17',
#    'author': 'SG Higgins',
#    'year': '2022',
#    'journal-title': 'Nature Protocols. Springer Science and Business Media LLC'},
#   {'key': 'pcbi.1012170.ref005',
#    'first-page': '3',
#    'article-title': 'The FAIR Guiding Principles for scientific data management and stewardship',
#    'author': 'MD Wilkinson',
#    'year': '2016',
#    'journal-title': 'Scientific Data. Springer Science and Business Media LLC'},
#   {'key': 'pcbi.1012170.ref006',
#    'author': 'ZB MED—Information Centre for Life Sciences',
#    'year': '2021',
#    'journal-title': 'ELN Guide. ZB MED—Informationszentrum Lebenswissenschaften'},
#   {'key': 'pcbi.1012170.ref007',
#    'unstructured': 'ELN Finder [cited 2023 Dec 04]. In: ELN Finder [Internet]. Germany: ZB MED—Information Centre for Life Sciences & University and State Library Darmstadt. Available from: https://eln-finder.ulb.tu-darmstadt.de/home.'},
#   {'key': 'pcbi.1012170.ref008',
#    'article-title': 'Electronic Lab Notebook Comparison Matrix',
#    'author': 'Harvard Longwood Medical Area Research Data Management Working Group',
#    'year': '2021',
#    'journal-title': 'Zenodo'},
#   {'key': 'pcbi.1012170.ref009',
#    'author': 'S. Bungers',
#    'year': '2023',
#    'journal-title': 'The Electronic Lab Notebook in 2023: A comprehensive guide.'},
#   {'key': 'pcbi.1012170.ref010',
#    'unstructured': 'How To Choose The Best Electronic Lab Notebook Software. [cited 2024 Mar 01]. In: SciNote Blog [Internet]. Middleton: SciNote 2023. [about 8 screens]. Available from: https://www.scinote.net/blog/electronic-lab-notebook-guide/.'},
#   {'key': 'pcbi.1012170.ref011',
#    'unstructured': 'Electronic Research Notebooks. [cited 2024 Mar 01]. In: University of Cambridge Data Management Guide [Internet]. Cambridge: University of Cambridge; 2024. [about 4 screens]. Available from: https://www.data.cam.ac.uk/data-management-guide/electronic-research-notebooks.'},
#   {'key': 'pcbi.1012170.ref012',
#    'unstructured': 'How ELNs are Shaping R&D Workflows For a More Competitive Future. Uncountable Solutions Guide. [cited 2024 Mar 01]. Available from: https://www.uncountable.com/try/free-guide-electronic-laboratory-notebooks-eln-guide.'},
#   {'key': 'pcbi.1012170.ref013',
#    'article-title': 'eLabFTW: An open source laboratory notebook for research labs',
#    'author': 'N CARPi',
#    'year': '2017',
#    'journal-title': 'GitHub'},
#   {'key': 'pcbi.1012170.ref014',
#    'unstructured': 'ELN demos. [cited 2024 Mar 01]. In: KIT Scientific Computing Center (SCC) [Internet]. Karlsruhe: Scientific Computing Center. 2024. [about 1 screen]. Available from: https://demo.chemotion.scc.kit.edu/.'},
#   {'key': 'pcbi.1012170.ref015',
#    'unstructured': 'Wiki-authors. Vendor lock-in. 2023 Sep 15 [cited 2023 Dec 04]. In: Wikipedia [Internet]. San Francisco: Wikimedia Foundation 2023. [about 3 screens]. Available from: https://en.wikipedia.org/wiki/Vendor_lock-in.'},
#   {'key': 'pcbi.1012170.ref016',
#    'article-title': 'Diskussionspapier Standard4ELN.',
#    'author': 'ZB MED—Information Centre for Life Sciences',
#    'year': '2023',
#    'journal-title': 'ZB MED—Informationszentrum Lebenswissenschaften'},
#   {'key': 'pcbi.1012170.ref017',
#    'unstructured': 'Durbin P. The ELN Consortium. [cited 04 Dec 2023]. In: GitHub [Internet]. San Francisco: GitHub. 2023. Available from: https://github.com/TheELNConsortium.'},
#   {'key': 'pcbi.1012170.ref018',
#    'article-title': 'The ELN File Format. [cited 2023 Dec 04]. In: GitHub',
#    'author': 'S Brinckmann',
#    'year': '2023',
#    'journal-title': 'San Francisco: GitHub'},
#   {'key': 'pcbi.1012170.ref019',
#    'author': 'Wiki-authors',
#    'year': '2023',
#    'journal-title': 'Usability testing'},
#   {'key': 'pcbi.1012170.ref020',
#    'doi-asserted-by': 'crossref',
#    'first-page': 'e1004525',
#    'DOI': '10.1371/journal.pcbi.1004525',
#    'article-title': 'Ten Simple Rules for Creating a Good Data Management Plan',
#    'volume': '11',
#    'author': 'WK Michener',
#    'year': '2015',
#    'journal-title': 'PLoS Comput Biol.'},
#   {'key': 'pcbi.1012170.ref021',
#    'doi-asserted-by': 'crossref',
#    'first-page': '2',
#    'DOI': '10.12688/f1000research.7628.1',
#    'article-title': 'A pocket guide to electronic laboratory notebooks in the academic life sciences',
#    'volume': '5',
#    'author': 'U Dirnagl',
#    'year': '2016',
#    'journal-title': 'F1000Res'},
#   {'key': 'pcbi.1012170.ref022',
#    'unstructured': 'Best Practice Use Guide. [cited 2024 Mar 01]. In: eLabJournal Documentation [Internet]. Groningen: eLabJournal; 2023. [about 1 screen]. Available from: https://www.elabjournal.com/doc/BestPractiseUseGuide.html.'},
#   {'key': 'pcbi.1012170.ref023',
#    'unstructured': 'eLabFTW pricing. [cited 2024 Mar 01]. In: eLabFTW [Internet]. Paris: Deltablot; 2024. [about 3 screens]. Available from: https://www.deltablot.com/elabftw/.'},
#   {'key': 'pcbi.1012170.ref024',
#    'unstructured': 'ZB MED—Information Centre for Life Sciences. Electronic Lab Notebooks (ELN) | Screencast—Infos—und mehr [Video]. 2022 Mar 10. Available from: https://www.youtube.com/playlist?list=PLJYlS0FDTMq17tvYMeuI2Ct5XtykRFy0K.'},
#   {'key': 'pcbi.1012170.ref025',
#    'article-title': 'Community Meeting I, 4:00 p.m.',
#    'author': 'H Uzun',
#    'year': '2024',
#    'journal-title': 'CET, 07 March 2024'},
#   {'key': 'pcbi.1012170.ref026',
#    'volume-title': 'API. 2012 [cited 2024 Mar 01]. In: eLabFTW’s documentation',
#    'author': 'N. CARPi',
#    'year': '2022'},
#   {'key': 'pcbi.1012170.ref027',
#    'article-title': 'Research Space and iRODS Partner to Enable Virtual File Storage and Meta-Data Solutions for Institutional Research Data Management.',
#    'author': 'V. Plankytė',
#    'year': '2022'},
#   {'key': 'pcbi.1012170.ref028',
#    'unstructured': 'Automating Lab Processes with API [Guide with Examples]. [cited 2024 Mar 01]. In: SciNote Blog [Internet]. Middleton: SciNote; 2023. [about 4 screens]. Available from: https://www.scinote.net/blog/automating-lab-processes-with-apis/.'},
#   {'key': 'pcbi.1012170.ref029',
#    'doi-asserted-by': 'crossref',
#    'first-page': '146',
#    'DOI': '10.21105/joss.00146',
#    'article-title': 'eLabFTW: An open source laboratory notebook for research labs',
#    'volume': '2',
#    'author': 'N CARPi',
#    'year': '2017',
#    'journal-title': 'J Open Source Softw'},
#   {'key': 'pcbi.1012170.ref030',
#    'unstructured': 'Tools For Analysis Of Data Stored In Openbis. 2023 Apr 17 [cited 2024 Mar 01]. In: OpenBIS Documentation [Internet]. Portland: Read the Docs; 2022. [about 3 screens]. Available from: https://openbis.readthedocs.io/en/20.10.x/user-documentation/general-users/tools-for-analysis-of-data-stored-in-openbis.html.'},
#   {'key': 'pcbi.1012170.ref031',
#    'year': '2014',
#    'journal-title': 'Research Data: labfolder and figshare cooperate to facilitate dissemination of scientific findings.'}],
#  'container-title': ['PLOS Computational Biology'],
#  'original-title': [],
#  'language': 'en',
#  'link': [{'URL': 'https://dx.plos.org/10.1371/journal.pcbi.1012170',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'deposited': {'date-parts': [[2024, 6, 20]],
#   'date-time': '2024-06-20T17:38:32Z',
#   'timestamp': 1718905112000},
#  'score': 1,
#  'resource': {'primary': {'URL': 'https://dx.plos.org/10.1371/journal.pcbi.1012170'}},
#  'subtitle': [],
#  'editor': [{'given': 'Russell',
#    'family': 'Schwartz',
#    'sequence': 'first',
#    'affiliation': []}],
#  'short-title': [],
#  'issued': {'date-parts': [[2024, 6, 20]]},
#  'references-count': 31,
#  'journal-issue': {'issue': '6',
#   'published-online': {'date-parts': [[2024, 6, 20]]}},
#  'URL': 'http://dx.doi.org/10.1371/journal.pcbi.1012170',
#  'relation': {},
#  'ISSN': ['1553-7358'],
#  'issn-type': [{'value': '1553-7358', 'type': 'electronic'}],
#  'subject': [],
#  'published': {'date-parts': [[2024, 6, 20]]}}

# %%
print(json.dumps(doi_data, indent=2))
# Out:
# {
#   "status": "ok",
#   "message-type": "work",
#   "message-version": "1.0.0",
#   "message": {
#     "indexed": {
#       "date-parts": [
#         [
#           2024,
#           6,
#           21
#         ]
#       ],
#       "date-time": "2024-06-21T00:23:38Z",
#       "timestamp": 1718929418656
#     },
#     "reference-count": 31,
#     "publisher": "Public Library of Science (PLoS)",
#     "issue": "6",
#     "license": [
#       {
#         "start": {
#           "date-parts": [
#             [
#               2024,
#               6,
#               20
#             ]
#           ],
#           "date-time": "2024-06-20T00:00:00Z",
#           "timestamp": 1718841600000
#         },
#         "content-version": "vor",
#         "delay-in-days": 0,
#         "URL": "http://creativecommons.org/licenses/by/4.0/"
#       }
#     ],
#     "funder": [
#       {
#         "DOI": "10.13039/501100001659",
#         "name": "Deutsche Forschungsgemeinschaft",
#         "doi-asserted-by": "publisher",
#         "award": [
#           "460129525"
#         ],
#         "id": [
#           {
#             "id": "10.13039/501100001659",
#             "id-type": "DOI",
#             "asserted-by": "publisher"
#           }
#         ]
#       },
#       {
#         "DOI": "10.13039/501100001659",
#         "name": "Deutsche Forschungsgemeinschaft",
#         "doi-asserted-by": "publisher",
#         "award": [
#           "442326535"
#         ],
#         "id": [
#           {
#             "id": "10.13039/501100001659",
#             "id-type": "DOI",
#             "asserted-by": "publisher"
#           }
#         ]
#       }
#     ],
#     "content-domain": {
#       "domain": [
#         "www.ploscompbiol.org"
#       ],
#       "crossmark-restriction": false
#     },
#     "short-container-title": [
#       "PLoS Comput Biol"
#     ],
#     "DOI": "10.1371/journal.pcbi.1012170",
#     "type": "journal-article",
#     "created": {
#       "date-parts": [
#         [
#           2024,
#           6,
#           20
#         ]
#       ],
#       "date-time": "2024-06-20T17:38:21Z",
#       "timestamp": 1718905101000
#     },
#     "page": "e1012170",
#     "update-policy": "http://dx.doi.org/10.1371/journal.pcbi.corrections_policy",
#     "source": "Crossref",
#     "is-referenced-by-count": 0,
#     "title": [
#       "Ten simple rules for implementing electronic lab notebooks (ELNs)"
#     ],
#     "prefix": "10.1371",
#     "volume": "20",
#     "author": [
#       {
#         "ORCID": "http://orcid.org/0000-0002-9421-8582",
#         "authenticated-orcid": true,
#         "given": "Justine",
#         "family": "Vandendorpe",
#         "sequence": "first",
#         "affiliation": []
#       },
#       {
#         "ORCID": "http://orcid.org/0000-0002-8431-6613",
#         "authenticated-orcid": true,
#         "given": "Beatrix",
#         "family": "Adam",
#         "sequence": "additional",
#         "affiliation": []
#       },
#       {
#         "ORCID": "http://orcid.org/0000-0002-0363-3837",
#         "authenticated-orcid": true,
#         "given": "Jeanne",
#         "family": "Wilbrandt",
#         "sequence": "additional",
#         "affiliation": []
#       },
#       {
#         "given": "Birte",
#         "family": "Lindst\u00e4dt",
#         "sequence": "additional",
#         "affiliation": []
#       },
#       {
#         "given": "Konrad U.",
#         "family": "F\u00f6rstner",
#         "sequence": "additional",
#         "affiliation": []
#       }
#     ],
#     "member": "340",
#     "published-online": {
#       "date-parts": [
#         [
#           2024,
#           6,
#           20
#         ]
#       ]
#     },
#     "reference": [
#       {
#         "key": "pcbi.1012170.ref001",
#         "first-page": "269",
#         "article-title": "How to pick an electronic laboratory notebook",
#         "volume": "560",
#         "author": "R. Kwok",
#         "year": "2018",
#         "journal-title": "Nature. Springer Science and Business Media LLC"
#       },
#       {
#         "key": "pcbi.1012170.ref002",
#         "doi-asserted-by": "crossref",
#         "first-page": "78",
#         "DOI": "10.1515/abitech-2016-0013",
#         "article-title": "Elektronische Laborb\u00fccher im Forschungsdatenmanagement\u2013Eine neue Aufgabe f\u00fcr Bibliotheken?",
#         "volume": "36",
#         "author": "Krause",
#         "year": "2016",
#         "journal-title": "ABI Technik. Walter de Gruyter GmbH"
#       },
#       {
#         "key": "pcbi.1012170.ref003",
#         "volume-title": "Longwood Medical Area Research Data Management Working Group (LMA RDMWG)",
#         "author": "Electronic Lab Notebooks",
#         "year": "2023"
#       },
#       {
#         "key": "pcbi.1012170.ref004",
#         "doi-asserted-by": "crossref",
#         "first-page": "179",
#         "DOI": "10.1038/s41596-021-00645-8",
#         "article-title": "Considerations for implementing electronic laboratory notebooks in an academic research environment",
#         "volume": "17",
#         "author": "SG Higgins",
#         "year": "2022",
#         "journal-title": "Nature Protocols. Springer Science and Business Media LLC"
#       },
#       {
#         "key": "pcbi.1012170.ref005",
#         "first-page": "3",
#         "article-title": "The FAIR Guiding Principles for scientific data management and stewardship",
#         "author": "MD Wilkinson",
#         "year": "2016",
#         "journal-title": "Scientific Data. Springer Science and Business Media LLC"
#       },
#       {
#         "key": "pcbi.1012170.ref006",
#         "author": "ZB MED\u2014Information Centre for Life Sciences",
#         "year": "2021",
#         "journal-title": "ELN Guide. ZB MED\u2014Informationszentrum Lebenswissenschaften"
#       },
#       {
#         "key": "pcbi.1012170.ref007",
#         "unstructured": "ELN Finder [cited 2023 Dec 04]. In: ELN Finder [Internet]. Germany: ZB MED\u2014Information Centre for Life Sciences & University and State Library Darmstadt. Available from: https://eln-finder.ulb.tu-darmstadt.de/home."
#       },
#       {
#         "key": "pcbi.1012170.ref008",
#         "article-title": "Electronic Lab Notebook Comparison Matrix",
#         "author": "Harvard Longwood Medical Area Research Data Management Working Group",
#         "year": "2021",
#         "journal-title": "Zenodo"
#       },
#       {
#         "key": "pcbi.1012170.ref009",
#         "author": "S. Bungers",
#         "year": "2023",
#         "journal-title": "The Electronic Lab Notebook in 2023: A comprehensive guide."
#       },
#       {
#         "key": "pcbi.1012170.ref010",
#         "unstructured": "How To Choose The Best Electronic Lab Notebook Software. [cited 2024 Mar 01]. In: SciNote Blog [Internet]. Middleton: SciNote 2023. [about 8 screens]. Available from: https://www.scinote.net/blog/electronic-lab-notebook-guide/."
#       },
#       {
#         "key": "pcbi.1012170.ref011",
#         "unstructured": "Electronic Research Notebooks. [cited 2024 Mar 01]. In: University of Cambridge Data Management Guide [Internet]. Cambridge: University of Cambridge; 2024. [about 4 screens]. Available from: https://www.data.cam.ac.uk/data-management-guide/electronic-research-notebooks."
#       },
#       {
#         "key": "pcbi.1012170.ref012",
#         "unstructured": "How ELNs are Shaping R&D Workflows For a More Competitive Future. Uncountable Solutions Guide. [cited 2024 Mar 01]. Available from: https://www.uncountable.com/try/free-guide-electronic-laboratory-notebooks-eln-guide."
#       },
#       {
#         "key": "pcbi.1012170.ref013",
#         "article-title": "eLabFTW: An open source laboratory notebook for research labs",
#         "author": "N CARPi",
#         "year": "2017",
#         "journal-title": "GitHub"
#       },
#       {
#         "key": "pcbi.1012170.ref014",
#         "unstructured": "ELN demos. [cited 2024 Mar 01]. In: KIT Scientific Computing Center (SCC) [Internet]. Karlsruhe: Scientific Computing Center. 2024. [about 1 screen]. Available from: https://demo.chemotion.scc.kit.edu/."
#       },
#       {
#         "key": "pcbi.1012170.ref015",
#         "unstructured": "Wiki-authors. Vendor lock-in. 2023 Sep 15 [cited 2023 Dec 04]. In: Wikipedia [Internet]. San Francisco: Wikimedia Foundation 2023. [about 3 screens]. Available from: https://en.wikipedia.org/wiki/Vendor_lock-in."
#       },
#       {
#         "key": "pcbi.1012170.ref016",
#         "article-title": "Diskussionspapier Standard4ELN.",
#         "author": "ZB MED\u2014Information Centre for Life Sciences",
#         "year": "2023",
#         "journal-title": "ZB MED\u2014Informationszentrum Lebenswissenschaften"
#       },
#       {
#         "key": "pcbi.1012170.ref017",
#         "unstructured": "Durbin P. The ELN Consortium. [cited 04 Dec 2023]. In: GitHub [Internet]. San Francisco: GitHub. 2023. Available from: https://github.com/TheELNConsortium."
#       },
#       {
#         "key": "pcbi.1012170.ref018",
#         "article-title": "The ELN File Format. [cited 2023 Dec 04]. In: GitHub",
#         "author": "S Brinckmann",
#         "year": "2023",
#         "journal-title": "San Francisco: GitHub"
#       },
#       {
#         "key": "pcbi.1012170.ref019",
#         "author": "Wiki-authors",
#         "year": "2023",
#         "journal-title": "Usability testing"
#       },
#       {
#         "key": "pcbi.1012170.ref020",
#         "doi-asserted-by": "crossref",
#         "first-page": "e1004525",
#         "DOI": "10.1371/journal.pcbi.1004525",
#         "article-title": "Ten Simple Rules for Creating a Good Data Management Plan",
#         "volume": "11",
#         "author": "WK Michener",
#         "year": "2015",
#         "journal-title": "PLoS Comput Biol."
#       },
#       {
#         "key": "pcbi.1012170.ref021",
#         "doi-asserted-by": "crossref",
#         "first-page": "2",
#         "DOI": "10.12688/f1000research.7628.1",
#         "article-title": "A pocket guide to electronic laboratory notebooks in the academic life sciences",
#         "volume": "5",
#         "author": "U Dirnagl",
#         "year": "2016",
#         "journal-title": "F1000Res"
#       },
#       {
#         "key": "pcbi.1012170.ref022",
#         "unstructured": "Best Practice Use Guide. [cited 2024 Mar 01]. In: eLabJournal Documentation [Internet]. Groningen: eLabJournal; 2023. [about 1 screen]. Available from: https://www.elabjournal.com/doc/BestPractiseUseGuide.html."
#       },
#       {
#         "key": "pcbi.1012170.ref023",
#         "unstructured": "eLabFTW pricing. [cited 2024 Mar 01]. In: eLabFTW [Internet]. Paris: Deltablot; 2024. [about 3 screens]. Available from: https://www.deltablot.com/elabftw/."
#       },
#       {
#         "key": "pcbi.1012170.ref024",
#         "unstructured": "ZB MED\u2014Information Centre for Life Sciences. Electronic Lab Notebooks (ELN) | Screencast\u2014Infos\u2014und mehr [Video]. 2022 Mar 10. Available from: https://www.youtube.com/playlist?list=PLJYlS0FDTMq17tvYMeuI2Ct5XtykRFy0K."
#       },
#       {
#         "key": "pcbi.1012170.ref025",
#         "article-title": "Community Meeting I, 4:00 p.m.",
#         "author": "H Uzun",
#         "year": "2024",
#         "journal-title": "CET, 07 March 2024"
#       },
#       {
#         "key": "pcbi.1012170.ref026",
#         "volume-title": "API. 2012 [cited 2024 Mar 01]. In: eLabFTW\u2019s documentation",
#         "author": "N. CARPi",
#         "year": "2022"
#       },
#       {
#         "key": "pcbi.1012170.ref027",
#         "article-title": "Research Space and iRODS Partner to Enable Virtual File Storage and Meta-Data Solutions for Institutional Research Data Management.",
#         "author": "V. Plankyt\u0117",
#         "year": "2022"
#       },
#       {
#         "key": "pcbi.1012170.ref028",
#         "unstructured": "Automating Lab Processes with API [Guide with Examples]. [cited 2024 Mar 01]. In: SciNote Blog [Internet]. Middleton: SciNote; 2023. [about 4 screens]. Available from: https://www.scinote.net/blog/automating-lab-processes-with-apis/."
#       },
#       {
#         "key": "pcbi.1012170.ref029",
#         "doi-asserted-by": "crossref",
#         "first-page": "146",
#         "DOI": "10.21105/joss.00146",
#         "article-title": "eLabFTW: An open source laboratory notebook for research labs",
#         "volume": "2",
#         "author": "N CARPi",
#         "year": "2017",
#         "journal-title": "J Open Source Softw"
#       },
#       {
#         "key": "pcbi.1012170.ref030",
#         "unstructured": "Tools For Analysis Of Data Stored In Openbis. 2023 Apr 17 [cited 2024 Mar 01]. In: OpenBIS Documentation [Internet]. Portland: Read the Docs; 2022. [about 3 screens]. Available from: https://openbis.readthedocs.io/en/20.10.x/user-documentation/general-users/tools-for-analysis-of-data-stored-in-openbis.html."
#       },
#       {
#         "key": "pcbi.1012170.ref031",
#         "year": "2014",
#         "journal-title": "Research Data: labfolder and figshare cooperate to facilitate dissemination of scientific findings."
#       }
#     ],
#     "container-title": [
#       "PLOS Computational Biology"
#     ],
#     "original-title": [],
#     "language": "en",
#     "link": [
#       {
#         "URL": "https://dx.plos.org/10.1371/journal.pcbi.1012170",
#         "content-type": "unspecified",
#         "content-version": "vor",
#         "intended-application": "similarity-checking"
#       }
#     ],
#     "deposited": {
#       "date-parts": [
#         [
#           2024,
#           6,
#           20
#         ]
#       ],
#       "date-time": "2024-06-20T17:38:32Z",
#       "timestamp": 1718905112000
#     },
#     "score": 1,
#     "resource": {
#       "primary": {
#         "URL": "https://dx.plos.org/10.1371/journal.pcbi.1012170"
#       }
#     },
#     "subtitle": [],
#     "editor": [
#       {
#         "given": "Russell",
#         "family": "Schwartz",
#         "sequence": "first",
#         "affiliation": []
#       }
#     ],
#     "short-title": [],
#     "issued": {
#       "date-parts": [
#         [
#           2024,
#           6,
#           20
#         ]
#       ]
#     },
#     "references-count": 31,
#     "journal-issue": {
#       "issue": "6",
#       "published-online": {
#         "date-parts": [
#           [
#             2024,
#             6,
#             20
#           ]
#         ]
#       }
#     },
#     "URL": "http://dx.doi.org/10.1371/journal.pcbi.1012170",
#     "relation": {},
#     "ISSN": [
#       "1553-7358"
#     ],
#     "issn-type": [
#       {
#         "value": "1553-7358",
#         "type": "electronic"
#       }
#     ],
#     "subject": [],
#     "published": {
#       "date-parts": [
#         [
#           2024,
#           6,
#           20
#         ]
#       ]
#     }
#   }
# }

# %%
# We can chain the keys to unpack the nested dictionary. 
doi_data["message"]["short-container-title"]
# Out:
# ['PLoS Comput Biol']

# %%
# As we get list as a value of the key "short-container-title" we use the 
# index to get the first element ("[0]")
doi_data["message"]["short-container-title"][0]
# Out:
# 'PLoS Comput Biol'

# %%
doi_data["message"]["title"]
# Out:
# ['Ten simple rules for implementing electronic lab notebooks (ELNs)']

# %%
doi_data["message"]["title"][0]
# Out:
# 'Ten simple rules for implementing electronic lab notebooks (ELNs)'

# %%
doi_data["message"]["author"]
# Out:
# [{'ORCID': 'http://orcid.org/0000-0002-9421-8582',
#   'authenticated-orcid': True,
#   'given': 'Justine',
#   'family': 'Vandendorpe',
#   'sequence': 'first',
#   'affiliation': []},
#  {'ORCID': 'http://orcid.org/0000-0002-8431-6613',
#   'authenticated-orcid': True,
#   'given': 'Beatrix',
#   'family': 'Adam',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'ORCID': 'http://orcid.org/0000-0002-0363-3837',
#   'authenticated-orcid': True,
#   'given': 'Jeanne',
#   'family': 'Wilbrandt',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'given': 'Birte',
#   'family': 'Lindstädt',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'given': 'Konrad U.',
#   'family': 'Förstner',
#   'sequence': 'additional',
#   'affiliation': []}]

# %%
doi_data["message"]["publisher"]
# Out:
# 'Public Library of Science (PLoS)'

# %%
doi_data["message"]["publisher"][0]
# Out:
# 'P'

# %%
# Side node - a string can also be addressed via an index and the 
# character of that position be returned - here the first character "A" 
# with index 0.
my_name = "Alice"

# %%
my_name[0]
# Out:
# 'A'

# %%
dois = ["10.1371/journal.pcbi.1004668",
        "10.21105/joss.01035",
        "10.1038/35057062",
        "10.21105/joss.01006"]

# %%
# For appyling this to several DOI we can use a 
# for loops that iterates through the list
for doi in dois:
    print("- " + doi)
    full_url = base_url + doi
    doi_json_data = urllib.request.urlopen(full_url).read()
    doi_data = json.loads(doi_json_data)
    short_journal_title = doi_data["message"]["short-container-title"][0]
    title = doi_data["message"]["title"][0]
    print("  - " + short_journal_title)
    print("  - " + title)
print("Done with data extraction")
# Out:
# - 10.1371/journal.pcbi.1004668
#   - PLoS Comput Biol
#   - A Quick Introduction to Version Control with Git and GitHub
# - 10.21105/joss.01035
#   - JOSS
#   - nasapower: A NASA POWER Global Meteorology, Surface Solar Energy and Climatology Data Client for R
# - 10.1038/35057062
#   - Nature
#   - Initial sequencing and analysis of the human genome
# - 10.21105/joss.01006
#   - JOSS
#   - SeqTools: A python package for easy transformation, combination and evaluation of large datasets.
# Done with data extraction
